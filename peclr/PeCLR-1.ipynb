# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive/summer/src"
# Out:
# converter.py  fh_utils.py  PeCLR-1.ipynb   __pycache__
# data	      models	   pred_manual.py  src

# %% [markdown]
# Create coor

# %%
# !python3 "/content/drive/MyDrive/summer/src/converter.py"

# %%
# !python3 "/content/drive/MyDrive/summer/src/classifier_model.py"
# Out:
# Epoch 1
# -------------------------------
# loss: 1.930543  [    0/ 3920]
# loss: 1.898090  [ 1600/ 3920]
# loss: 1.857932  [ 3200/ 3920]
# Test Error:
#  Accuracy: 34.2%, Avg loss: 1.857689
#
# Epoch 2
# -------------------------------
# loss: 1.846204  [    0/ 3920]
# loss: 1.792168  [ 1600/ 3920]
# loss: 1.515305  [ 3200/ 3920]
# Test Error:
#  Accuracy: 39.9%, Avg loss: 1.556967
#
# Epoch 3
# -------------------------------
# loss: 1.585981  [    0/ 3920]
# loss: 1.249643  [ 1600/ 3920]
# loss: 1.175636  [ 3200/ 3920]
# Test Error:
#  Accuracy: 64.9%, Avg loss: 1.162463
#
# Epoch 4
# -------------------------------
# loss: 1.043208  [    0/ 3920]
# loss: 1.023117  [ 1600/ 3920]
# loss: 0.738828  [ 3200/ 3920]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.900524
#
# Epoch 5
# -------------------------------
# loss: 0.862457  [    0/ 3920]
# loss: 1.088688  [ 1600/ 3920]
# loss: 0.616581  [ 3200/ 3920]
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.712373
#
# Epoch 6
# ...

# %%
# !python3 "/content/drive/MyDrive/summer/src/pred_manual.py"
# Out:
# [[-0.22011096 -0.14073219  0.88147974]
#  [-0.25267823 -0.10917037  0.88087902]
#  [-0.28267093 -0.0917899   0.87891407]
#  [-0.31805961 -0.09681246  0.8827919 ]
#  [-0.3681077  -0.107541    0.89382658]
#  [-0.29667246 -0.10257068  0.83105583]
#  [-0.32302074 -0.09739066  0.81225195]
#  [-0.34598553 -0.09792891  0.80773468]
#  [-0.37048013 -0.10055047  0.7997879 ]
#  [-0.30479839 -0.13058453  0.82693739]
#  [-0.33665097 -0.12818348  0.81085634]
#  [-0.3639379  -0.12799639  0.80468121]
#  [-0.39194555 -0.12763491  0.7920186 ]
#  [-0.29988775 -0.16243953  0.84064951]
#  [-0.33085389 -0.15844982  0.82501059]
#  [-0.36044769 -0.15864509  0.81606388]
#  [-0.39162796 -0.15437503  0.80498781]
#  [-0.29546905 -0.18536893  0.85679588]
#  [-0.31557496 -0.19132273  0.85027227]
#  [-0.33405623 -0.19436498  0.84288092]
#  [-0.35115712 -0.19327062  0.82967291]]
# *****
# [[171 125]
#  [187 152]
#  [132 152]
#  [123 125]
#  [133  98]
#  [142  80]
#  [160 167]
#  [101 155]
#  [ 87 125]
#  [ 98  99]
# ...
